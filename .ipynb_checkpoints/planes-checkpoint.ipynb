# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reading the csv file into the pandas dataframe
data = pd.read_csv('data.csv')
data
# Out:
#         Unnamed: 0 hexcode  mode squawk    flight altitude speed heading  \
# 0                0  800b05  S                         5850
# 1                1  800b05  S                         5850   211     217
# 2                2  800b05  S                         5850   211     217
# 3                3  8006fc  S                        38350
# 4                4  800b05  S                         5850   211     217
# 5                5  8006fc  S                        38350
# 6                6  800b05  S                         5850   211     217
# 7                7  8006fc  S                        38375
# 8                8  800b05  S                         5850   211     217
# 9                9  8006fc  S                        38375
# 10              10  800b05  S                         5850   211     217
# 11              11  8006fc  S                        38375
# 12              12  800b05  S                         5850   211     217
# 13              13  8006fc  S                        38375
# 14              14  800b05  S                         5850   210     217
# 15              15  8006fc  S                        38375
# 16              16  800b05  S                         5850   210     217
# 17              17  8006fc  S                        38375
# 18              18  800b05  S                         5850   210     217
# 19              19  8004fd  S                        30525
# 20              20  8006fc  S                        38375
# 21              21  800b05  S                         5850   210     217
# 22              22  8004fd  S                        30525
# 23              23  8006fc  S                        38375
# 24              24  800b05  S                         5850   210     217
# 25              25  8004fd  S                        30525
# 26              26  8006fc  S                        38375
# 27              27  800b05  S                         5850   210     217
# 28              28  8004fd  S                        30525
# 29              29  8006fc  S                        38425
# ...            ...     ...   ...    ...       ...      ...   ...     ...
# 604185      604185  8004fd  S      0644  AIC265      28375   435     187
# 604186      604186  70c0a2  S      4747  OMA253      41000   440     115
# 604187      604187  8007b7  S      0230  LEP703      13025
# 604188      604188  8005b8  S      0207  SEJ282      38000   461     306
# 604189      604189  80067c  S      2713  JLL4165     35975   469     325
# 604190      604190  8001e6  S      2711  JLL4238     35975   474     357
# 604191      604191  800af6  S      0310  SEJ215      37000   446     170
# 604192      604192  800589  S      2712  AIC501      15550   329     358
# 604193      604193  8004fd  S      0644  AIC265      28375   435     187
# 604194      604194  70c0a2  S      4747  OMA253      41000   440     115
# 604195      604195  8007b7  S      0230  LEP703      13025
# 604196      604196  8005b8  S      0207  SEJ282      38000   461     306
# 604197      604197  80067c  S      2713  JLL4165     35975   469     325
# 604198      604198  8001e6  S      2711  JLL4238     35975   474     357
# 604199      604199  800af6  S      0310  SEJ215      37000   446     170
# 604200      604200  800589  S      2712  AIC501      15550   329     358
# 604201      604201  8004fd  S      0644  AIC265      28375   435     187
# 604202      604202  70c0a2  S      4747  OMA253      41000   440     115
# 604203      604203  8007b7  S      0230  LEP703      13025
# 604204      604204  8005b8  S      0207  SEJ282      38000   461     306
# 604205      604205  80067c  S      2713  JLL4165     35975   469     325
# 604206      604206  8001e6  S      2711  JLL4238     35975   474     357
# 604207      604207  800af6  S      0310  SEJ215      37000   446     170
# 604208      604208  800589  S      2712  AIC501      15550   329     358
# 604209      604209  8004fd  S      0644  AIC265      28375   435     187
# 604210      604210  70c0a2  S      4747  OMA253      41000   440     115
# 604211      604211  8007b7  S      0230  LEP703      13025
# 604212      604212  8005b8  S      0207  SEJ282      38000   461     306
# 604213      604213  80067c  S      2713  JLL4165     35975   469     325
# 604214      604214  8001e6  S      2711  JLL4238     35975   474     357
#
#        latitude longitude  signal  messages  ti                   timestamp
# 0                              23         1   0         2014-10-19 07:12:15
# 1                              23         2   0  2014-10-19 07:12:15.001000
# 2                              23         2   1         2014-10-19 07:12:16
# 3                               6         1   0  2014-10-19 07:12:16.001000
# 4                              23         2   1  2014-10-19 07:12:16.002000
# 5                               6         1   0  2014-10-19 07:12:16.003000
# 6                              23         3   0  2014-10-19 07:12:16.004000
# 7                               6         3   0  2014-10-19 07:12:16.005000
# 8                              22         4   0  2014-10-19 07:12:16.006000
# 9                               6         3   1         2014-10-19 07:12:17
# 10                             22         4   1  2014-10-19 07:12:17.001000
# 11                              6         3   1  2014-10-19 07:12:17.002000
# 12       13.262    77.484      21         6   0  2014-10-19 07:12:17.003000
# 13                              6         3   1  2014-10-19 07:12:17.004000
# 14       13.262    77.484      23         8   0  2014-10-19 07:12:17.005000
# 15                              6         3   1  2014-10-19 07:12:17.006000
# 16       13.261    77.484      24        10   0  2014-10-19 07:12:17.007000
# 17                              6         3   2         2014-10-19 07:12:18
# 18       13.261    77.484      24        10   1  2014-10-19 07:12:18.001000
# 19                             11         1   0  2014-10-19 07:12:18.002000
# 20                              6         3   2  2014-10-19 07:12:18.003000
# 21       13.261    77.484      24        11   0  2014-10-19 07:12:18.004000
# 22                             11         1   0  2014-10-19 07:12:18.005000
# 23                              6         3   2  2014-10-19 07:12:18.006000
# 24       13.261    77.484      27        13   0  2014-10-19 07:12:18.007000
# 25                             11         1   1         2014-10-19 07:12:19
# 26                              6         3   3  2014-10-19 07:12:19.001000
# 27       13.261    77.484      27        13   1  2014-10-19 07:12:19.002000
# 28                             11         1   1  2014-10-19 07:12:19.003000
# 29                              6         4   0  2014-10-19 07:12:19.004000
# ...         ...       ...     ...       ...  ..                         ...
# 604185   12.185    77.329       7       200   4  2014-10-19 13:31:41.010000
# 604186   14.982    76.564      11      1112   1  2014-10-19 13:31:41.011000
# 604187                          6       225   2  2014-10-19 13:31:41.012000
# 604188   15.047    77.767      12      1762   0  2014-10-19 13:31:41.013000
# 604189   15.224    76.480      10      2150   2  2014-10-19 13:31:41.014000
# 604190   15.577    77.850       5       626  20  2014-10-19 13:31:41.015000
# 604191                          7        86   3  2014-10-19 13:31:41.016000
# 604192   13.607    77.709      10       249   4  2014-10-19 13:31:41.017000
# 604193   12.185    77.329       7       200   4  2014-10-19 13:31:41.018000
# 604194   14.982    76.564      12      1115   0  2014-10-19 13:31:41.019000
# 604195                          6       225   2  2014-10-19 13:31:41.020000
# 604196   15.047    77.767      12      1762   0  2014-10-19 13:31:41.021000
# 604197   15.224    76.480      10      2150   2  2014-10-19 13:31:41.022000
# 604198   15.577    77.850       5       626  20  2014-10-19 13:31:41.023000
# 604199                          7        86   3  2014-10-19 13:31:41.024000
# 604200   13.607    77.709      10       250   0  2014-10-19 13:31:41.025000
# 604201   12.185    77.329       7       200   4  2014-10-19 13:31:41.026000
# 604202   14.982    76.564      12      1115   0  2014-10-19 13:31:41.027000
# 604203                          6       225   2  2014-10-19 13:31:41.028000
# 604204   15.049    77.765      11      1766   0  2014-10-19 13:31:41.029000
# 604205   15.224    76.480      10      2150   2  2014-10-19 13:31:41.030000
# 604206   15.577    77.850       5       626  20  2014-10-19 13:31:41.031000
# 604207                          7        86   4         2014-10-19 13:31:42
# 604208   13.607    77.709      10       250   1  2014-10-19 13:31:42.001000
# 604209   12.185    77.329       7       200   5  2014-10-19 13:31:42.002000
# 604210   14.982    76.564      12      1115   1  2014-10-19 13:31:42.003000
# 604211                          6       225   3  2014-10-19 13:31:42.004000
# 604212   15.049    77.765      11      1767   0  2014-10-19 13:31:42.005000
# 604213   15.228    76.476       9      2151   0  2014-10-19 13:31:42.006000
# 604214   15.577    77.850       5       626  21  2014-10-19 13:31:42.007000
#
# [604215 rows x 14 columns]

# %%
# Remove the column that is not required
del data['Unnamed: 0']
data
# Out:
#        hexcode  mode squawk    flight altitude speed heading latitude  \
# 0       800b05  S                         5850
# 1       800b05  S                         5850   211     217
# 2       800b05  S                         5850   211     217
# 3       8006fc  S                        38350
# 4       800b05  S                         5850   211     217
# 5       8006fc  S                        38350
# 6       800b05  S                         5850   211     217
# 7       8006fc  S                        38375
# 8       800b05  S                         5850   211     217
# 9       8006fc  S                        38375
# 10      800b05  S                         5850   211     217
# 11      8006fc  S                        38375
# 12      800b05  S                         5850   211     217   13.262
# 13      8006fc  S                        38375
# 14      800b05  S                         5850   210     217   13.262
# 15      8006fc  S                        38375
# 16      800b05  S                         5850   210     217   13.261
# 17      8006fc  S                        38375
# 18      800b05  S                         5850   210     217   13.261
# 19      8004fd  S                        30525
# 20      8006fc  S                        38375
# 21      800b05  S                         5850   210     217   13.261
# 22      8004fd  S                        30525
# 23      8006fc  S                        38375
# 24      800b05  S                         5850   210     217   13.261
# 25      8004fd  S                        30525
# 26      8006fc  S                        38375
# 27      800b05  S                         5850   210     217   13.261
# 28      8004fd  S                        30525
# 29      8006fc  S                        38425
# ...        ...   ...    ...       ...      ...   ...     ...      ...
# 604185  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604186  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604187  8007b7  S      0230  LEP703      13025
# 604188  8005b8  S      0207  SEJ282      38000   461     306   15.047
# 604189  80067c  S      2713  JLL4165     35975   469     325   15.224
# 604190  8001e6  S      2711  JLL4238     35975   474     357   15.577
# 604191  800af6  S      0310  SEJ215      37000   446     170
# 604192  800589  S      2712  AIC501      15550   329     358   13.607
# 604193  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604194  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604195  8007b7  S      0230  LEP703      13025
# 604196  8005b8  S      0207  SEJ282      38000   461     306   15.047
# 604197  80067c  S      2713  JLL4165     35975   469     325   15.224
# 604198  8001e6  S      2711  JLL4238     35975   474     357   15.577
# 604199  800af6  S      0310  SEJ215      37000   446     170
# 604200  800589  S      2712  AIC501      15550   329     358   13.607
# 604201  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604202  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604203  8007b7  S      0230  LEP703      13025
# 604204  8005b8  S      0207  SEJ282      38000   461     306   15.049
# 604205  80067c  S      2713  JLL4165     35975   469     325   15.224
# 604206  8001e6  S      2711  JLL4238     35975   474     357   15.577
# 604207  800af6  S      0310  SEJ215      37000   446     170
# 604208  800589  S      2712  AIC501      15550   329     358   13.607
# 604209  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604210  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604211  8007b7  S      0230  LEP703      13025
# 604212  8005b8  S      0207  SEJ282      38000   461     306   15.049
# 604213  80067c  S      2713  JLL4165     35975   469     325   15.228
# 604214  8001e6  S      2711  JLL4238     35975   474     357   15.577
#
#        longitude  signal  messages  ti                   timestamp
# 0                     23         1   0         2014-10-19 07:12:15
# 1                     23         2   0  2014-10-19 07:12:15.001000
# 2                     23         2   1         2014-10-19 07:12:16
# 3                      6         1   0  2014-10-19 07:12:16.001000
# 4                     23         2   1  2014-10-19 07:12:16.002000
# 5                      6         1   0  2014-10-19 07:12:16.003000
# 6                     23         3   0  2014-10-19 07:12:16.004000
# 7                      6         3   0  2014-10-19 07:12:16.005000
# 8                     22         4   0  2014-10-19 07:12:16.006000
# 9                      6         3   1         2014-10-19 07:12:17
# 10                    22         4   1  2014-10-19 07:12:17.001000
# 11                     6         3   1  2014-10-19 07:12:17.002000
# 12        77.484      21         6   0  2014-10-19 07:12:17.003000
# 13                     6         3   1  2014-10-19 07:12:17.004000
# 14        77.484      23         8   0  2014-10-19 07:12:17.005000
# 15                     6         3   1  2014-10-19 07:12:17.006000
# 16        77.484      24        10   0  2014-10-19 07:12:17.007000
# 17                     6         3   2         2014-10-19 07:12:18
# 18        77.484      24        10   1  2014-10-19 07:12:18.001000
# 19                    11         1   0  2014-10-19 07:12:18.002000
# 20                     6         3   2  2014-10-19 07:12:18.003000
# 21        77.484      24        11   0  2014-10-19 07:12:18.004000
# 22                    11         1   0  2014-10-19 07:12:18.005000
# 23                     6         3   2  2014-10-19 07:12:18.006000
# 24        77.484      27        13   0  2014-10-19 07:12:18.007000
# 25                    11         1   1         2014-10-19 07:12:19
# 26                     6         3   3  2014-10-19 07:12:19.001000
# 27        77.484      27        13   1  2014-10-19 07:12:19.002000
# 28                    11         1   1  2014-10-19 07:12:19.003000
# 29                     6         4   0  2014-10-19 07:12:19.004000
# ...          ...     ...       ...  ..                         ...
# 604185    77.329       7       200   4  2014-10-19 13:31:41.010000
# 604186    76.564      11      1112   1  2014-10-19 13:31:41.011000
# 604187                 6       225   2  2014-10-19 13:31:41.012000
# 604188    77.767      12      1762   0  2014-10-19 13:31:41.013000
# 604189    76.480      10      2150   2  2014-10-19 13:31:41.014000
# 604190    77.850       5       626  20  2014-10-19 13:31:41.015000
# 604191                 7        86   3  2014-10-19 13:31:41.016000
# 604192    77.709      10       249   4  2014-10-19 13:31:41.017000
# 604193    77.329       7       200   4  2014-10-19 13:31:41.018000
# 604194    76.564      12      1115   0  2014-10-19 13:31:41.019000
# 604195                 6       225   2  2014-10-19 13:31:41.020000
# 604196    77.767      12      1762   0  2014-10-19 13:31:41.021000
# 604197    76.480      10      2150   2  2014-10-19 13:31:41.022000
# 604198    77.850       5       626  20  2014-10-19 13:31:41.023000
# 604199                 7        86   3  2014-10-19 13:31:41.024000
# 604200    77.709      10       250   0  2014-10-19 13:31:41.025000
# 604201    77.329       7       200   4  2014-10-19 13:31:41.026000
# 604202    76.564      12      1115   0  2014-10-19 13:31:41.027000
# 604203                 6       225   2  2014-10-19 13:31:41.028000
# 604204    77.765      11      1766   0  2014-10-19 13:31:41.029000
# 604205    76.480      10      2150   2  2014-10-19 13:31:41.030000
# 604206    77.850       5       626  20  2014-10-19 13:31:41.031000
# 604207                 7        86   4         2014-10-19 13:31:42
# 604208    77.709      10       250   1  2014-10-19 13:31:42.001000
# 604209    77.329       7       200   5  2014-10-19 13:31:42.002000
# 604210    76.564      12      1115   1  2014-10-19 13:31:42.003000
# 604211                 6       225   3  2014-10-19 13:31:42.004000
# 604212    77.765      11      1767   0  2014-10-19 13:31:42.005000
# 604213    76.476       9      2151   0  2014-10-19 13:31:42.006000
# 604214    77.850       5       626  21  2014-10-19 13:31:42.007000
#
# [604215 rows x 13 columns]

# %%
data.describe()
# Out:
#               signal       messages             ti
# count  604215.000000  604215.000000  604215.000000
# mean       13.204141     985.592594       9.962154
# std        15.195620    1297.133100      15.145329
# min         4.000000       1.000000       0.000000
# 25%         7.000000      97.000000       0.000000
# 50%         9.000000     448.000000       2.000000
# 75%        13.000000    1340.000000      14.000000
# max       182.000000    6469.000000      60.000000

# %%
# Gives the unique aircrafts in the data
unique_hexcode = data.hexcode.unique()

# %%
type(unique_hexcode)
# Out:
# numpy.ndarray

# %%
unique_hexcode
# Out:
# array(['800b05', '8006fc', '8004fd', '8004fb', '8004b8', '800b14',
#        '800549', '80015a', '8001d9', '800afb', '800af0', '8005dd',
#        '4007f1', '80070f', '80047b', '8007f7', '800603', '80068b',
#        '800647', '8004cd', '800b1a', '80052e', '8005b8', '8006fe',
#        '800595', '80053d', '8007f2', '80003d', '89609b', '800af9',
#        '800657', '8007b7', '06a024', '800408', '800717', '80058a',
#        '80068a', '3c7063', '800712', '70c0a8', '800655', '896309',
#        '800af6', '8961a3', '800656', '80041f', '800b09', '8007c2',
#        '800670', '773000', '800400', '06a01f', '80015d', '80064f',
#        '800b18', '8006e8', '80046c', '8007b3', '89604c', '800af4',
#        '8007c9', '800b2b', '80051b', '8004d9', '8005fd', '8004b5',
#        '06a191', '800b0b', '8003c1', '800466', '800738', '800030',
#        '8960d9', '800488', '800b0a', '89407a', '800489', '80067f',
#        '8001dc', '800b11', '75008d', '8963b1', '8007c0', '8007c4',
#        '800617', '80068f', '8007b8', '800627', '80074d', '800671',
#        '8007e6', '8005d5', '3c4586', '800af1', '8963a5', '800654',
#        '80068e', '8007e7', '8001d3', '8007c8', '8000c2', '8000c0',
#        '8004f8', '80062b', '800628', '750204', '8004fa', '8007ef',
#        '06a052', '8004bd', '896310', '80054d', '80068c', '8007f0',
#        '89620d', '896212', '800538', '80064c', '30003a', '800624',
#        '800469', '80047c', '80067c', '8006e1', '8007dd', '8001e6',
#        '800031', '06a0aa', '70c0a2', '800589'], dtype=object)

# %%
unique_hexcode.size
# Out:
# 130

# %%
# Finding the number and percentage of domestic Planes and International Planes ( Indian planes start with the code '800')

# %%
hexcode_first_three = pd.Series(unique_hexcode.astype('str')).str[:3]

# %%
hexcode_first_three
# Out:
# 0      800
# 1      800
# 2      800
# 3      800
# 4      800
# 5      800
# 6      800
# 7      800
# 8      800
# 9      800
# 10     800
# 11     800
# 12     400
# 13     800
# 14     800
# 15     800
# 16     800
# 17     800
# 18     800
# 19     800
# 20     800
# 21     800
# 22     800
# 23     800
# 24     800
# 25     800
# 26     800
# 27     800
# 28     896
# 29     800
#       ...
# 100    800
# 101    800
# 102    800
# 103    800
# 104    800
# 105    750
# 106    800
# 107    800
# 108    06a
# 109    800
# 110    896
# 111    800
# 112    800
# 113    800
# 114    896
# 115    896
# 116    800
# 117    800
# 118    300
# 119    800
# 120    800
# 121    800
# 122    800
# 123    800
# 124    800
# 125    800
# 126    800
# 127    06a
# 128    70c
# 129    800
# dtype: object

# %%
Type_Aircraft_Boolean = hexcode_first_three == '800'
Type_Aircraft_Boolean
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28     False
# 29      True
#        ...
# 100     True
# 101     True
# 102     True
# 103     True
# 104     True
# 105    False
# 106     True
# 107     True
# 108    False
# 109     True
# 110    False
# 111     True
# 112     True
# 113     True
# 114    False
# 115    False
# 116     True
# 117     True
# 118    False
# 119     True
# 120     True
# 121     True
# 122     True
# 123     True
# 124     True
# 125     True
# 126     True
# 127    False
# 128    False
# 129     True
# dtype: bool

# %%
Domestic = sum(Type_Aircraft_Boolean)
Domestic
# Out:
# 105

# %%
International = Type_Aircraft_Boolean.size - Domestic
International
# Out:
# 25

# %%
Percentage_Domestic = round(Domestic*100.0/(Domestic+International),1)
print 'The Percentage of Domestic aircrafts is ' + str(Percentage_Domestic)+' %'
print 'The Percentage of International aircrafts is ' + str(100-Percentage_Domestic)+' %'
# Out:
# The Percentage of Domestic aircrafts is 80.8 %
# The Percentage of International aircrafts is 19.2 %

# %%
#Plotting chart of percentage of Domestic and International
labels = 'Domestic', 'International'
sizes = [Domestic,International]
colors = ['yellowgreen','lightskyblue']
explode = (0.1,0)
plt.figure(1)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.show()

# %%
unique_flight = data.flight.str.strip().unique() # removes the unwanted white spaces

# %%
unique_flight
# Out:
# array(['', 'BDA403', 'AIC640', 'SEJ442', 'GOW283', 'SEJ871', 'IGO516',
#        'BAW118', 'IGO111', 'JAI256', 'GOW321', 'IGO421', 'SEJ502',
#        'AIC515', 'JAI405', 'AIC667', 'JAI2735', 'IGO427', 'IGO545',
#        'IGO126', 'SEJ281', 'JAI489', 'SEJ291', 'JAI411', 'AIC603',
#        'UAE544', 'AIC263', 'SEJ1073', 'GEC8378', 'IGO411', 'IGO424',
#        'OMA252', 'LEP666', 'SEJ1031', 'SEJ3301', 'AIC466', 'ETD474',
#        'JAI2363', 'SEJ227', 'IAD1212', 'SEJ3022', 'AIC570', 'IGO457',
#        'QTR956', 'SEJ3145', 'GOW395', 'JAI824', 'SEJ1046', 'IGO409',
#        'UAE564', 'IGO377', 'SEJ501', 'IGO455', 'IGO315', 'IGO065',
#        'JAI2612', 'IGO356', 'IGO376', 'AIC517', 'QTR8882', 'IGO109',
#        'GOW116', 'AIC976', 'GOW348', 'AIC803', 'UAE346', 'AIC604',
#        'SEJ152', 'IAD1323', 'VTANF', 'IGO298', 'GFA060', 'MAS8217',
#        'FDB551', 'IAD1123', 'JAI412', 'IGO428', 'IGO151', 'SEJ521',
#        'JAI807', 'JAI465', 'JAI2400', 'IGO502', 'LEP667', 'SEJ236',
#        'SEJ917', 'SEJ344', 'SEJ1032', 'LEP696', 'BOX531', 'IGO271',
#        'IGO464', 'SEJ224', 'RJD402', 'LEP648', 'IGO115', 'IGO118',
#        'IGO102', 'JAI342', 'LEP664', 'SEJ3303', 'AIC668', 'JLL4607',
#        'SEJ131', 'SEJ3302', 'IAD1722', 'UAE545', 'SEJ528', 'SEJ3313',
#        'JAI255', 'VTRVL', 'SEJ1074', 'IGO452', 'JAI2755', 'SEJ342',
#        'IGO155', 'IGO422', 'UAE565', 'AIC505', 'JAI2308', 'MAS174',
#        'IAD1124', 'AIC671', 'IGO431', 'UAE433', 'SEJ271', 'QTR845',
#        'IGO238', 'IGO461', 'SEJ451', 'UAE345', 'UAE409', 'IGO433',
#        'EXV9141', 'GOW115', 'IGO317', 'IGO465', 'JAI466', 'JAI450',
#        'JLL4056', 'AIC639', 'IGO407', 'SEJ282', 'JLL4165', 'QTR938',
#        'AIC467', 'JLL4238', 'IGO432', 'SEJ3304', 'OMA253', 'LEP703',
#        'AIC265', 'AIC501', 'SEJ215'], dtype=object)

# %%
unique_flight.size
# Out:
# 154

# %%
# Market share of each airline. Indigo, SpiceJet and so on...

# Info on data from Wikipedia
# IATA airline designators, sometimes called IATA reservation codes, are two-character codes assigned by the International Air Transport Association (IATA) to the world's airlines

#After an airline is delisted, IATA can make the code available for reuse after six months and can issue "controlled duplicates". Controlled duplicates are issued to regional airlines whose destinations are not likely to overlap, so that the same code is shared by two airlines. The controlled duplicate is denoted here, and in IATA literature, with an asterisk (*). An example of this is the code "6Y", which refers to both Mid Airlines, a charter airline in Sudan, and Med Airways, a charter airline in Lebanon.


# The ICAO airline designator is a code assigned by the International Civil Aviation Organization (ICAO) to aircraft operating agencies, aeronautical authorities, and services related to international aviation, each of whom is allocated both a three-letter designator and a telephony designator. These codes are unique by airline, unlike the IATA airline designator codes 
#An example is:
#Operator: American Airlines
#Three-letter designator: AAL (the original ICAO-two-letter-designator AA was used until 1987 and is also the IATA code of the airline)
#Telephony designator: AMERICAN

# %%
#Query the first three letters which is the ICAO
# IATA	ICAO	Callsign
# AI	 AIC	AIRINDIA

# %%
unique_flight_first_three = pd.Series(unique_flight.astype('str')).str[:3]
unique_flight_first_three
# Out:
# 0
# 1      BDA
# 2      AIC
# 3      SEJ
# 4      GOW
# 5      SEJ
# 6      IGO
# 7      BAW
# 8      IGO
# 9      JAI
# 10     GOW
# 11     IGO
# 12     SEJ
# 13     AIC
# 14     JAI
# 15     AIC
# 16     JAI
# 17     IGO
# 18     IGO
# 19     IGO
# 20     SEJ
# 21     JAI
# 22     SEJ
# 23     JAI
# 24     AIC
# 25     UAE
# 26     AIC
# 27     SEJ
# 28     GEC
# 29     IGO
#       ...
# 124    UAE
# 125    SEJ
# 126    QTR
# 127    IGO
# 128    IGO
# 129    SEJ
# 130    UAE
# 131    UAE
# 132    IGO
# 133    EXV
# 134    GOW
# 135    IGO
# 136    IGO
# 137    JAI
# 138    JAI
# 139    JLL
# 140    AIC
# 141    IGO
# 142    SEJ
# 143    JLL
# 144    QTR
# 145    AIC
# 146    JLL
# 147    IGO
# 148    SEJ
# 149    OMA
# 150    LEP
# 151    AIC
# 152    AIC
# 153    SEJ
# dtype: object

# %%
unique_flight_first_three = unique_flight_first_three.replace('',np.nan)
unique_flight_first_three
# Out:
# 0      NaN
# 1      BDA
# 2      AIC
# 3      SEJ
# 4      GOW
# 5      SEJ
# 6      IGO
# 7      BAW
# 8      IGO
# 9      JAI
# 10     GOW
# 11     IGO
# 12     SEJ
# 13     AIC
# 14     JAI
# 15     AIC
# 16     JAI
# 17     IGO
# 18     IGO
# 19     IGO
# 20     SEJ
# 21     JAI
# 22     SEJ
# 23     JAI
# 24     AIC
# 25     UAE
# 26     AIC
# 27     SEJ
# 28     GEC
# 29     IGO
#       ...
# 124    UAE
# 125    SEJ
# 126    QTR
# 127    IGO
# 128    IGO
# 129    SEJ
# 130    UAE
# 131    UAE
# 132    IGO
# 133    EXV
# 134    GOW
# 135    IGO
# 136    IGO
# 137    JAI
# 138    JAI
# 139    JLL
# 140    AIC
# 141    IGO
# 142    SEJ
# 143    JLL
# 144    QTR
# 145    AIC
# 146    JLL
# 147    IGO
# 148    SEJ
# 149    OMA
# 150    LEP
# 151    AIC
# 152    AIC
# 153    SEJ
# dtype: object

# %%
Flight_counts = unique_flight_first_three.value_counts(dropna=False)
Flight_counts = Flight_counts.reset_index(drop=False)
Flight_counts.rename(columns={'index': 'ICAO', 0:'Count'}, inplace=True)
Flight_counts
# Out:
#    ICAO  Count
# 0   IGO     37
# 1   SEJ     32
# 2   AIC     18
# 3   JAI     18
# 4   UAE      8
# 5   LEP      6
# 6   GOW      6
# 7   IAD      5
# 8   JLL      4
# 9   QTR      4
# 10  MAS      2
# 11  OMA      2
# 12  RJD      1
# 13  GEC      1
# 14  ETD      1
# 15  EXV      1
# 16  GFA      1
# 17  VTR      1
# 18  BOX      1
# 19  BDA      1
# 20  FDB      1
# 21  BAW      1
# 22  VTA      1
# 23  NaN      1

# %%
Flight_counts['ICAO'][0]
# Out:
# 'IGO'

# %%
#Count the number of carriers in the day

# %%
airline = pd.read_csv('./Airlines/Airlines_callsign_IATA_ICAO.csv')
airline
# Out:
#      Unnamed: 0                       Callsign       Tag  Number IATA  ICAO
# 0             0  Dornier Aviation Nigeria Aiep  DO / DAV       3  DO    DAV
# 1             1         LATAM Airlines Ecuador  XL / LNE       6  XL    LNE
# 2             2                          9 Air  AQ / JYH       8  AQ    JYH
# 3             3                        ABX Air  GB / ABX      14  GB    ABX
# 4             4                  Adria Airways  JP / ADR      13  JP    ADR
# 5             5                Aegean Airlines  A3 / AEE      48  A3    AEE
# 6             6                     Aer Lingus  EI / EIN      63  EI    EIN
# 7             7               Aero Contractors  NG / NIG       8  NG    NIG
# 8             8                       Aero Vip  WV / RVP       7  WV    RVP
# 9             9                    Aero-Dienst       ADN      16  NaN   ADN
# 10           10                       Aeroflot  SU / AFL     185  SU    AFL
# 11           11          Aerolineas Argentinas  AR / ARG      56  AR    ARG
# 12           12                 Aerolineas Mas  N3 / MAF       3  N3    MAF
# 13           13                      AeroLogic  3S / BOX       9  3S    BOX
# 14           14                        Aeromar  VW / TAO      14  VW    TAO
# 15           15                     Aeromexico  AM / AMX      69  AM    AMX
# 16           16             Aeromexico Connect  5D / SLI      67  5D    SLI
# 17           17                     Aeropostal  VH / ALV       6  VH    ALV
# 18           18                      AeroUnion  6R / TNO       6  6R    TNO
# 19           19                 Afric Aviation  L8 / EKG       1  L8    EKG
# 20           20          Africa World Airlines  AW / AFW       3  AW    AFW
# 21           21        African Express Airways  XU / AXK       2  XU    AXK
# 22           22              Afriqiyah Airways  8U / AAW       5  8U    AAW
# 23           23                     Aigle Azur  ZI / AAF      10  ZI    AAF
# 24           24                    Air Algerie  AH / DAH      55  AH    DAH
# 25           25                      Air Alsie  6I / MMD      27  6I    MMD
# 26           26           Air Antilles Express  3S / GUY       6  3S    GUY
# 27           27                     Air Arabia  G9 / ABY      36  G9    ABY
# 28           28               Air Arabia Egypt  E5 / RBG       1  E5    RBG
# 29           29              Air Arabia Jordan  9P / JAD       3  9P    JAD
# ..          ...                            ...       ...     ...  ...   ...
# 893         893                      Wamos Air  EB / PLM       5  EB    PLM
# 894         894         Warbelows Air Ventures  4W / WAV       6  4W    WAV
# 895         895                 Wasaya Airways  WT / WSG      24  WT    WSG
# 896         896                   WDL Aviation       WDL       2  NaN   WDL
# 897         897                    Welcome Air  2W / WLC       1  2W    WLC
# 898         898                West Air Sweden       SWN      40  NaN   SWN
# 899         899             West Wind Aviation       WEW      33  NaN   WEW
# 900         900                        WestJet  WS / WJA     118  WS    WJA
# 901         901                 WestJet Encore  WR / WEN      30  WR    WEN
# 902         902                          White  WI / WHT       5  WI    WHT
# 903         903                        Wideroe  WF / WIF      41  WF    WIF
# 904         904                Wiggins Airways       WIG      16  NaN   WIG
# 905         905                         Winair  WM / WIA       1  WM    WIA
# 906         906              Windrose Airlines  7W / WRC       6  7W    WRC
# 907         907                      Wings Air  IW / WON      48  IW    WON
# 908         908               Wings of Lebanon  W7 / WLB       1  W7    WLB
# 909         909                       Wizz Air  W6 / WZZ      71  W6    WZZ
# 910         910        World Atlantic Airlines  K8 / WAL       7  K8    WAL
# 911         911                        WOW Air  WW / WOW      11  WW    WOW
# 912         912                Xiamen Airlines  MF / CXA     145  MF    CXA
# 913         913              XL Airways France  SE / XLF       5  SE    XLF
# 914         914                   Xtra Airways  XP / CXP      10  XP    CXP
# 915         915               Yakutia Airlines  R3 / SYL      11  R3    SYL
# 916         916                 Yamal Airlines  YC / LLM      31  YC    LLM
# 917         917                         YanAir  YE / ANR       7  YE    ANR
# 918         918          Yangtze River Express  Y8 / YZR      25  Y8    YZR
# 919         919                        Yemenia  IY / IYE       5  IY    IYE
# 920         920                  Yeti Airlines  YT / NYT       2  YT    NYT
# 921         921                Zagros Airlines  ZO / IZG      18  ZO    IZG
# 922         922                      ZagrosJet  Z4 / GZQ       1  Z4    GZQ
#
# [923 rows x 6 columns]

# %%
del airline['Unnamed: 0']
airline
# Out:
#                           Callsign       Tag  Number IATA  ICAO
# 0    Dornier Aviation Nigeria Aiep  DO / DAV       3  DO    DAV
# 1           LATAM Airlines Ecuador  XL / LNE       6  XL    LNE
# 2                            9 Air  AQ / JYH       8  AQ    JYH
# 3                          ABX Air  GB / ABX      14  GB    ABX
# 4                    Adria Airways  JP / ADR      13  JP    ADR
# 5                  Aegean Airlines  A3 / AEE      48  A3    AEE
# 6                       Aer Lingus  EI / EIN      63  EI    EIN
# 7                 Aero Contractors  NG / NIG       8  NG    NIG
# 8                         Aero Vip  WV / RVP       7  WV    RVP
# 9                      Aero-Dienst       ADN      16  NaN   ADN
# 10                        Aeroflot  SU / AFL     185  SU    AFL
# 11           Aerolineas Argentinas  AR / ARG      56  AR    ARG
# 12                  Aerolineas Mas  N3 / MAF       3  N3    MAF
# 13                       AeroLogic  3S / BOX       9  3S    BOX
# 14                         Aeromar  VW / TAO      14  VW    TAO
# 15                      Aeromexico  AM / AMX      69  AM    AMX
# 16              Aeromexico Connect  5D / SLI      67  5D    SLI
# 17                      Aeropostal  VH / ALV       6  VH    ALV
# 18                       AeroUnion  6R / TNO       6  6R    TNO
# 19                  Afric Aviation  L8 / EKG       1  L8    EKG
# 20           Africa World Airlines  AW / AFW       3  AW    AFW
# 21         African Express Airways  XU / AXK       2  XU    AXK
# 22               Afriqiyah Airways  8U / AAW       5  8U    AAW
# 23                      Aigle Azur  ZI / AAF      10  ZI    AAF
# 24                     Air Algerie  AH / DAH      55  AH    DAH
# 25                       Air Alsie  6I / MMD      27  6I    MMD
# 26            Air Antilles Express  3S / GUY       6  3S    GUY
# 27                      Air Arabia  G9 / ABY      36  G9    ABY
# 28                Air Arabia Egypt  E5 / RBG       1  E5    RBG
# 29               Air Arabia Jordan  9P / JAD       3  9P    JAD
# ..                             ...       ...     ...  ...   ...
# 893                      Wamos Air  EB / PLM       5  EB    PLM
# 894         Warbelows Air Ventures  4W / WAV       6  4W    WAV
# 895                 Wasaya Airways  WT / WSG      24  WT    WSG
# 896                   WDL Aviation       WDL       2  NaN   WDL
# 897                    Welcome Air  2W / WLC       1  2W    WLC
# 898                West Air Sweden       SWN      40  NaN   SWN
# 899             West Wind Aviation       WEW      33  NaN   WEW
# 900                        WestJet  WS / WJA     118  WS    WJA
# 901                 WestJet Encore  WR / WEN      30  WR    WEN
# 902                          White  WI / WHT       5  WI    WHT
# 903                        Wideroe  WF / WIF      41  WF    WIF
# 904                Wiggins Airways       WIG      16  NaN   WIG
# 905                         Winair  WM / WIA       1  WM    WIA
# 906              Windrose Airlines  7W / WRC       6  7W    WRC
# 907                      Wings Air  IW / WON      48  IW    WON
# 908               Wings of Lebanon  W7 / WLB       1  W7    WLB
# 909                       Wizz Air  W6 / WZZ      71  W6    WZZ
# 910        World Atlantic Airlines  K8 / WAL       7  K8    WAL
# 911                        WOW Air  WW / WOW      11  WW    WOW
# 912                Xiamen Airlines  MF / CXA     145  MF    CXA
# 913              XL Airways France  SE / XLF       5  SE    XLF
# 914                   Xtra Airways  XP / CXP      10  XP    CXP
# 915               Yakutia Airlines  R3 / SYL      11  R3    SYL
# 916                 Yamal Airlines  YC / LLM      31  YC    LLM
# 917                         YanAir  YE / ANR       7  YE    ANR
# 918          Yangtze River Express  Y8 / YZR      25  Y8    YZR
# 919                        Yemenia  IY / IYE       5  IY    IYE
# 920                  Yeti Airlines  YT / NYT       2  YT    NYT
# 921                Zagros Airlines  ZO / IZG      18  ZO    IZG
# 922                      ZagrosJet  Z4 / GZQ       1  Z4    GZQ
#
# [923 rows x 5 columns]

# %%
airline
# Out:
#                           Callsign       Tag  Number IATA  ICAO
# 0    Dornier Aviation Nigeria Aiep  DO / DAV       3  DO    DAV
# 1           LATAM Airlines Ecuador  XL / LNE       6  XL    LNE
# 2                            9 Air  AQ / JYH       8  AQ    JYH
# 3                          ABX Air  GB / ABX      14  GB    ABX
# 4                    Adria Airways  JP / ADR      13  JP    ADR
# 5                  Aegean Airlines  A3 / AEE      48  A3    AEE
# 6                       Aer Lingus  EI / EIN      63  EI    EIN
# 7                 Aero Contractors  NG / NIG       8  NG    NIG
# 8                         Aero Vip  WV / RVP       7  WV    RVP
# 9                      Aero-Dienst       ADN      16  NaN   ADN
# 10                        Aeroflot  SU / AFL     185  SU    AFL
# 11           Aerolineas Argentinas  AR / ARG      56  AR    ARG
# 12                  Aerolineas Mas  N3 / MAF       3  N3    MAF
# 13                       AeroLogic  3S / BOX       9  3S    BOX
# 14                         Aeromar  VW / TAO      14  VW    TAO
# 15                      Aeromexico  AM / AMX      69  AM    AMX
# 16              Aeromexico Connect  5D / SLI      67  5D    SLI
# 17                      Aeropostal  VH / ALV       6  VH    ALV
# 18                       AeroUnion  6R / TNO       6  6R    TNO
# 19                  Afric Aviation  L8 / EKG       1  L8    EKG
# 20           Africa World Airlines  AW / AFW       3  AW    AFW
# 21         African Express Airways  XU / AXK       2  XU    AXK
# 22               Afriqiyah Airways  8U / AAW       5  8U    AAW
# 23                      Aigle Azur  ZI / AAF      10  ZI    AAF
# 24                     Air Algerie  AH / DAH      55  AH    DAH
# 25                       Air Alsie  6I / MMD      27  6I    MMD
# 26            Air Antilles Express  3S / GUY       6  3S    GUY
# 27                      Air Arabia  G9 / ABY      36  G9    ABY
# 28                Air Arabia Egypt  E5 / RBG       1  E5    RBG
# 29               Air Arabia Jordan  9P / JAD       3  9P    JAD
# ..                             ...       ...     ...  ...   ...
# 893                      Wamos Air  EB / PLM       5  EB    PLM
# 894         Warbelows Air Ventures  4W / WAV       6  4W    WAV
# 895                 Wasaya Airways  WT / WSG      24  WT    WSG
# 896                   WDL Aviation       WDL       2  NaN   WDL
# 897                    Welcome Air  2W / WLC       1  2W    WLC
# 898                West Air Sweden       SWN      40  NaN   SWN
# 899             West Wind Aviation       WEW      33  NaN   WEW
# 900                        WestJet  WS / WJA     118  WS    WJA
# 901                 WestJet Encore  WR / WEN      30  WR    WEN
# 902                          White  WI / WHT       5  WI    WHT
# 903                        Wideroe  WF / WIF      41  WF    WIF
# 904                Wiggins Airways       WIG      16  NaN   WIG
# 905                         Winair  WM / WIA       1  WM    WIA
# 906              Windrose Airlines  7W / WRC       6  7W    WRC
# 907                      Wings Air  IW / WON      48  IW    WON
# 908               Wings of Lebanon  W7 / WLB       1  W7    WLB
# 909                       Wizz Air  W6 / WZZ      71  W6    WZZ
# 910        World Atlantic Airlines  K8 / WAL       7  K8    WAL
# 911                        WOW Air  WW / WOW      11  WW    WOW
# 912                Xiamen Airlines  MF / CXA     145  MF    CXA
# 913              XL Airways France  SE / XLF       5  SE    XLF
# 914                   Xtra Airways  XP / CXP      10  XP    CXP
# 915               Yakutia Airlines  R3 / SYL      11  R3    SYL
# 916                 Yamal Airlines  YC / LLM      31  YC    LLM
# 917                         YanAir  YE / ANR       7  YE    ANR
# 918          Yangtze River Express  Y8 / YZR      25  Y8    YZR
# 919                        Yemenia  IY / IYE       5  IY    IYE
# 920                  Yeti Airlines  YT / NYT       2  YT    NYT
# 921                Zagros Airlines  ZO / IZG      18  ZO    IZG
# 922                      ZagrosJet  Z4 / GZQ       1  Z4    GZQ
#
# [923 rows x 5 columns]

# %%
airline.ICAO = airline.ICAO.str.strip()
airline
# Out:
#                           Callsign       Tag  Number IATA ICAO
# 0    Dornier Aviation Nigeria Aiep  DO / DAV       3  DO   DAV
# 1           LATAM Airlines Ecuador  XL / LNE       6  XL   LNE
# 2                            9 Air  AQ / JYH       8  AQ   JYH
# 3                          ABX Air  GB / ABX      14  GB   ABX
# 4                    Adria Airways  JP / ADR      13  JP   ADR
# 5                  Aegean Airlines  A3 / AEE      48  A3   AEE
# 6                       Aer Lingus  EI / EIN      63  EI   EIN
# 7                 Aero Contractors  NG / NIG       8  NG   NIG
# 8                         Aero Vip  WV / RVP       7  WV   RVP
# 9                      Aero-Dienst       ADN      16  NaN  ADN
# 10                        Aeroflot  SU / AFL     185  SU   AFL
# 11           Aerolineas Argentinas  AR / ARG      56  AR   ARG
# 12                  Aerolineas Mas  N3 / MAF       3  N3   MAF
# 13                       AeroLogic  3S / BOX       9  3S   BOX
# 14                         Aeromar  VW / TAO      14  VW   TAO
# 15                      Aeromexico  AM / AMX      69  AM   AMX
# 16              Aeromexico Connect  5D / SLI      67  5D   SLI
# 17                      Aeropostal  VH / ALV       6  VH   ALV
# 18                       AeroUnion  6R / TNO       6  6R   TNO
# 19                  Afric Aviation  L8 / EKG       1  L8   EKG
# 20           Africa World Airlines  AW / AFW       3  AW   AFW
# 21         African Express Airways  XU / AXK       2  XU   AXK
# 22               Afriqiyah Airways  8U / AAW       5  8U   AAW
# 23                      Aigle Azur  ZI / AAF      10  ZI   AAF
# 24                     Air Algerie  AH / DAH      55  AH   DAH
# 25                       Air Alsie  6I / MMD      27  6I   MMD
# 26            Air Antilles Express  3S / GUY       6  3S   GUY
# 27                      Air Arabia  G9 / ABY      36  G9   ABY
# 28                Air Arabia Egypt  E5 / RBG       1  E5   RBG
# 29               Air Arabia Jordan  9P / JAD       3  9P   JAD
# ..                             ...       ...     ...  ...  ...
# 893                      Wamos Air  EB / PLM       5  EB   PLM
# 894         Warbelows Air Ventures  4W / WAV       6  4W   WAV
# 895                 Wasaya Airways  WT / WSG      24  WT   WSG
# 896                   WDL Aviation       WDL       2  NaN  WDL
# 897                    Welcome Air  2W / WLC       1  2W   WLC
# 898                West Air Sweden       SWN      40  NaN  SWN
# 899             West Wind Aviation       WEW      33  NaN  WEW
# 900                        WestJet  WS / WJA     118  WS   WJA
# 901                 WestJet Encore  WR / WEN      30  WR   WEN
# 902                          White  WI / WHT       5  WI   WHT
# 903                        Wideroe  WF / WIF      41  WF   WIF
# 904                Wiggins Airways       WIG      16  NaN  WIG
# 905                         Winair  WM / WIA       1  WM   WIA
# 906              Windrose Airlines  7W / WRC       6  7W   WRC
# 907                      Wings Air  IW / WON      48  IW   WON
# 908               Wings of Lebanon  W7 / WLB       1  W7   WLB
# 909                       Wizz Air  W6 / WZZ      71  W6   WZZ
# 910        World Atlantic Airlines  K8 / WAL       7  K8   WAL
# 911                        WOW Air  WW / WOW      11  WW   WOW
# 912                Xiamen Airlines  MF / CXA     145  MF   CXA
# 913              XL Airways France  SE / XLF       5  SE   XLF
# 914                   Xtra Airways  XP / CXP      10  XP   CXP
# 915               Yakutia Airlines  R3 / SYL      11  R3   SYL
# 916                 Yamal Airlines  YC / LLM      31  YC   LLM
# 917                         YanAir  YE / ANR       7  YE   ANR
# 918          Yangtze River Express  Y8 / YZR      25  Y8   YZR
# 919                        Yemenia  IY / IYE       5  IY   IYE
# 920                  Yeti Airlines  YT / NYT       2  YT   NYT
# 921                Zagros Airlines  ZO / IZG      18  ZO   IZG
# 922                      ZagrosJet  Z4 / GZQ       1  Z4   GZQ
#
# [923 rows x 5 columns]

# %%
airline_ICAO = pd.merge(Flight_counts,airline,on='ICAO',how='left')
airline_ICAO
# Out:
#    ICAO  Count             Callsign       Tag  Number IATA
# 0   IGO     37      IndiGo Airlines  6E / IGO   112.0  6E
# 1   SEJ     32             SpiceJet  SG / SEJ    43.0  SG
# 2   AIC     18            Air India  AI / AIC   108.0  AI
# 3   JAI     18          Jet Airways  9W / JAI    96.0  9W
# 4   UAE      8             Emirates  EK / UAE   259.0  EK
# 5   LEP      6                  NaN       NaN     NaN  NaN
# 6   GOW      6               Go Air  G8 / GOW    21.0  G8
# 7   IAD      5        AirAsia India  I5 / IAD     6.0  I5
# 8   JLL      4              JetLite  S2 / JLL    14.0  S2
# 9   QTR      4        Qatar Airways  QR / QTR   173.0  QR
# 10  MAS      2    Malaysia Airlines  MH / MAS    85.0  MH
# 11  OMA      2             Oman Air  WY / OMA    45.0  WY
# 12  RJD      1  Rotana Jet Aviation  RG / RJD     4.0  RG
# 13  GEC      1      Lufthansa Cargo       GEC    17.0  NaN
# 14  ETD      1       Etihad Airways  EY / ETD   126.0  EY
# 15  EXV      1              FitsAir  8D / EXV     1.0  8D
# 16  GFA      1             Gulf Air  GF / GFA    29.0  GF
# 17  VTR      1                  NaN       NaN     NaN  NaN
# 18  BOX      1            AeroLogic  3S / BOX     9.0  3S
# 19  BDA      1   Blue Dart Aviation  BZ / BDA     5.0  BZ
# 20  FDB      1             FlyDubai  FZ / FDB    53.0  FZ
# 21  BAW      1      British Airways  BA / BAW   307.0  BA
# 22  VTA      1           Air Tahiti  VT / VTA    13.0  VT
# 23  NaN      1                  NaN       NaN     NaN  NaN

# %%
#Plotting pie chart of market share
labels = airline_ICAO.Callsign
sizes = airline_ICAO.Count
plt.figure(2)
plt.pie(sizes, labels=labels,startangle=140)
plt.show()

# %%
data
# Out:
#        hexcode  mode squawk    flight altitude speed heading latitude  \
# 0       800b05  S                         5850
# 1       800b05  S                         5850   211     217
# 2       800b05  S                         5850   211     217
# 3       8006fc  S                        38350
# 4       800b05  S                         5850   211     217
# 5       8006fc  S                        38350
# 6       800b05  S                         5850   211     217
# 7       8006fc  S                        38375
# 8       800b05  S                         5850   211     217
# 9       8006fc  S                        38375
# 10      800b05  S                         5850   211     217
# 11      8006fc  S                        38375
# 12      800b05  S                         5850   211     217   13.262
# 13      8006fc  S                        38375
# 14      800b05  S                         5850   210     217   13.262
# 15      8006fc  S                        38375
# 16      800b05  S                         5850   210     217   13.261
# 17      8006fc  S                        38375
# 18      800b05  S                         5850   210     217   13.261
# 19      8004fd  S                        30525
# 20      8006fc  S                        38375
# 21      800b05  S                         5850   210     217   13.261
# 22      8004fd  S                        30525
# 23      8006fc  S                        38375
# 24      800b05  S                         5850   210     217   13.261
# 25      8004fd  S                        30525
# 26      8006fc  S                        38375
# 27      800b05  S                         5850   210     217   13.261
# 28      8004fd  S                        30525
# 29      8006fc  S                        38425
# ...        ...   ...    ...       ...      ...   ...     ...      ...
# 604185  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604186  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604187  8007b7  S      0230  LEP703      13025
# 604188  8005b8  S      0207  SEJ282      38000   461     306   15.047
# 604189  80067c  S      2713  JLL4165     35975   469     325   15.224
# 604190  8001e6  S      2711  JLL4238     35975   474     357   15.577
# 604191  800af6  S      0310  SEJ215      37000   446     170
# 604192  800589  S      2712  AIC501      15550   329     358   13.607
# 604193  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604194  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604195  8007b7  S      0230  LEP703      13025
# 604196  8005b8  S      0207  SEJ282      38000   461     306   15.047
# 604197  80067c  S      2713  JLL4165     35975   469     325   15.224
# 604198  8001e6  S      2711  JLL4238     35975   474     357   15.577
# 604199  800af6  S      0310  SEJ215      37000   446     170
# 604200  800589  S      2712  AIC501      15550   329     358   13.607
# 604201  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604202  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604203  8007b7  S      0230  LEP703      13025
# 604204  8005b8  S      0207  SEJ282      38000   461     306   15.049
# 604205  80067c  S      2713  JLL4165     35975   469     325   15.224
# 604206  8001e6  S      2711  JLL4238     35975   474     357   15.577
# 604207  800af6  S      0310  SEJ215      37000   446     170
# 604208  800589  S      2712  AIC501      15550   329     358   13.607
# 604209  8004fd  S      0644  AIC265      28375   435     187   12.185
# 604210  70c0a2  S      4747  OMA253      41000   440     115   14.982
# 604211  8007b7  S      0230  LEP703      13025
# 604212  8005b8  S      0207  SEJ282      38000   461     306   15.049
# 604213  80067c  S      2713  JLL4165     35975   469     325   15.228
# 604214  8001e6  S      2711  JLL4238     35975   474     357   15.577
#
#        longitude  signal  messages  ti                   timestamp
# 0                     23         1   0         2014-10-19 07:12:15
# 1                     23         2   0  2014-10-19 07:12:15.001000
# 2                     23         2   1         2014-10-19 07:12:16
# 3                      6         1   0  2014-10-19 07:12:16.001000
# 4                     23         2   1  2014-10-19 07:12:16.002000
# 5                      6         1   0  2014-10-19 07:12:16.003000
# 6                     23         3   0  2014-10-19 07:12:16.004000
# 7                      6         3   0  2014-10-19 07:12:16.005000
# 8                     22         4   0  2014-10-19 07:12:16.006000
# 9                      6         3   1         2014-10-19 07:12:17
# 10                    22         4   1  2014-10-19 07:12:17.001000
# 11                     6         3   1  2014-10-19 07:12:17.002000
# 12        77.484      21         6   0  2014-10-19 07:12:17.003000
# 13                     6         3   1  2014-10-19 07:12:17.004000
# 14        77.484      23         8   0  2014-10-19 07:12:17.005000
# 15                     6         3   1  2014-10-19 07:12:17.006000
# 16        77.484      24        10   0  2014-10-19 07:12:17.007000
# 17                     6         3   2         2014-10-19 07:12:18
# 18        77.484      24        10   1  2014-10-19 07:12:18.001000
# 19                    11         1   0  2014-10-19 07:12:18.002000
# 20                     6         3   2  2014-10-19 07:12:18.003000
# 21        77.484      24        11   0  2014-10-19 07:12:18.004000
# 22                    11         1   0  2014-10-19 07:12:18.005000
# 23                     6         3   2  2014-10-19 07:12:18.006000
# 24        77.484      27        13   0  2014-10-19 07:12:18.007000
# 25                    11         1   1         2014-10-19 07:12:19
# 26                     6         3   3  2014-10-19 07:12:19.001000
# 27        77.484      27        13   1  2014-10-19 07:12:19.002000
# 28                    11         1   1  2014-10-19 07:12:19.003000
# 29                     6         4   0  2014-10-19 07:12:19.004000
# ...          ...     ...       ...  ..                         ...
# 604185    77.329       7       200   4  2014-10-19 13:31:41.010000
# 604186    76.564      11      1112   1  2014-10-19 13:31:41.011000
# 604187                 6       225   2  2014-10-19 13:31:41.012000
# 604188    77.767      12      1762   0  2014-10-19 13:31:41.013000
# 604189    76.480      10      2150   2  2014-10-19 13:31:41.014000
# 604190    77.850       5       626  20  2014-10-19 13:31:41.015000
# 604191                 7        86   3  2014-10-19 13:31:41.016000
# 604192    77.709      10       249   4  2014-10-19 13:31:41.017000
# 604193    77.329       7       200   4  2014-10-19 13:31:41.018000
# 604194    76.564      12      1115   0  2014-10-19 13:31:41.019000
# 604195                 6       225   2  2014-10-19 13:31:41.020000
# 604196    77.767      12      1762   0  2014-10-19 13:31:41.021000
# 604197    76.480      10      2150   2  2014-10-19 13:31:41.022000
# 604198    77.850       5       626  20  2014-10-19 13:31:41.023000
# 604199                 7        86   3  2014-10-19 13:31:41.024000
# 604200    77.709      10       250   0  2014-10-19 13:31:41.025000
# 604201    77.329       7       200   4  2014-10-19 13:31:41.026000
# 604202    76.564      12      1115   0  2014-10-19 13:31:41.027000
# 604203                 6       225   2  2014-10-19 13:31:41.028000
# 604204    77.765      11      1766   0  2014-10-19 13:31:41.029000
# 604205    76.480      10      2150   2  2014-10-19 13:31:41.030000
# 604206    77.850       5       626  20  2014-10-19 13:31:41.031000
# 604207                 7        86   4         2014-10-19 13:31:42
# 604208    77.709      10       250   1  2014-10-19 13:31:42.001000
# 604209    77.329       7       200   5  2014-10-19 13:31:42.002000
# 604210    76.564      12      1115   1  2014-10-19 13:31:42.003000
# 604211                 6       225   3  2014-10-19 13:31:42.004000
# 604212    77.765      11      1767   0  2014-10-19 13:31:42.005000
# 604213    76.476       9      2151   0  2014-10-19 13:31:42.006000
# 604214    77.850       5       626  21  2014-10-19 13:31:42.007000
#
# [604215 rows x 13 columns]

# %%
data['hexcode'][3]
# Out:
# '8006fc'

# %%
unique_flight[2]
# Out:
# 'AIC640'

# %%
data_hexcode_flight = data[['hexcode','flight']]

# %%
data_hexcode_flight
# Out:
#        hexcode    flight
# 0       800b05
# 1       800b05
# 2       800b05
# 3       8006fc
# 4       800b05
# 5       8006fc
# 6       800b05
# 7       8006fc
# 8       800b05
# 9       8006fc
# 10      800b05
# 11      8006fc
# 12      800b05
# 13      8006fc
# 14      800b05
# 15      8006fc
# 16      800b05
# 17      8006fc
# 18      800b05
# 19      8004fd
# 20      8006fc
# 21      800b05
# 22      8004fd
# 23      8006fc
# 24      800b05
# 25      8004fd
# 26      8006fc
# 27      800b05
# 28      8004fd
# 29      8006fc
# ...        ...       ...
# 604185  8004fd  AIC265
# 604186  70c0a2  OMA253
# 604187  8007b7  LEP703
# 604188  8005b8  SEJ282
# 604189  80067c  JLL4165
# 604190  8001e6  JLL4238
# 604191  800af6  SEJ215
# 604192  800589  AIC501
# 604193  8004fd  AIC265
# 604194  70c0a2  OMA253
# 604195  8007b7  LEP703
# 604196  8005b8  SEJ282
# 604197  80067c  JLL4165
# 604198  8001e6  JLL4238
# 604199  800af6  SEJ215
# 604200  800589  AIC501
# 604201  8004fd  AIC265
# 604202  70c0a2  OMA253
# 604203  8007b7  LEP703
# 604204  8005b8  SEJ282
# 604205  80067c  JLL4165
# 604206  8001e6  JLL4238
# 604207  800af6  SEJ215
# 604208  800589  AIC501
# 604209  8004fd  AIC265
# 604210  70c0a2  OMA253
# 604211  8007b7  LEP703
# 604212  8005b8  SEJ282
# 604213  80067c  JLL4165
# 604214  8001e6  JLL4238
#
# [604215 rows x 2 columns]

# %%
# Replace blank spaces which are six spaces. Hence, below are six spaces replaced by NaN

# %%
data_hexcode_flight_blankremoved_replacedbyNaN = data_hexcode_flight.replace('      ',np.nan,regex=True)

# %%
data_hexcode_flight_blankremoved_replacedbyNaN
# Out:
#        hexcode    flight
# 0       800b05       NaN
# 1       800b05       NaN
# 2       800b05       NaN
# 3       8006fc       NaN
# 4       800b05       NaN
# 5       8006fc       NaN
# 6       800b05       NaN
# 7       8006fc       NaN
# 8       800b05       NaN
# 9       8006fc       NaN
# 10      800b05       NaN
# 11      8006fc       NaN
# 12      800b05       NaN
# 13      8006fc       NaN
# 14      800b05       NaN
# 15      8006fc       NaN
# 16      800b05       NaN
# 17      8006fc       NaN
# 18      800b05       NaN
# 19      8004fd       NaN
# 20      8006fc       NaN
# 21      800b05       NaN
# 22      8004fd       NaN
# 23      8006fc       NaN
# 24      800b05       NaN
# 25      8004fd       NaN
# 26      8006fc       NaN
# 27      800b05       NaN
# 28      8004fd       NaN
# 29      8006fc       NaN
# ...        ...       ...
# 604185  8004fd  AIC265
# 604186  70c0a2  OMA253
# 604187  8007b7  LEP703
# 604188  8005b8  SEJ282
# 604189  80067c  JLL4165
# 604190  8001e6  JLL4238
# 604191  800af6  SEJ215
# 604192  800589  AIC501
# 604193  8004fd  AIC265
# 604194  70c0a2  OMA253
# 604195  8007b7  LEP703
# 604196  8005b8  SEJ282
# 604197  80067c  JLL4165
# 604198  8001e6  JLL4238
# 604199  800af6  SEJ215
# 604200  800589  AIC501
# 604201  8004fd  AIC265
# 604202  70c0a2  OMA253
# 604203  8007b7  LEP703
# 604204  8005b8  SEJ282
# 604205  80067c  JLL4165
# 604206  8001e6  JLL4238
# 604207  800af6  SEJ215
# 604208  800589  AIC501
# 604209  8004fd  AIC265
# 604210  70c0a2  OMA253
# 604211  8007b7  LEP703
# 604212  8005b8  SEJ282
# 604213  80067c  JLL4165
# 604214  8001e6  JLL4238
#
# [604215 rows x 2 columns]

# %%
# Drop duplicates, for example - 800af1-NaN is present more than once in rows 0, 3, 7 and so on. After the below
# step, only row 0 with 800af1 - NaN will be present

# %%
data_hexcode_flight_noduplicates_NaN = data_hexcode_flight_blankremoved_replacedbyNaN.drop_duplicates(subset=['hexcode','flight'])

# %%
data_hexcode_flight_noduplicates_NaN
# Out:
#        hexcode    flight
# 0       800b05       NaN
# 3       8006fc       NaN
# 19      8004fd       NaN
# 31      8004fb       NaN
# 47      8004b8       NaN
# 97      800b14       NaN
# 169     800549       NaN
# 350     800b05  BDA403
# 495     8004fd  AIC640
# 694     80015a       NaN
# 945     8004b8  SEJ442
# 2064    8001d9       NaN
# 3818    800549  GOW283
# 4289    8001d9  SEJ871
# 5477    800afb       NaN
# 5732    800af0       NaN
# 5824    8005dd       NaN
# 5920    800af0  IGO516
# 5989    4007f1       NaN
# 6559    80070f       NaN
# 6650    80047b       NaN
# 6690    8007f7       NaN
# 6761    4007f1  BAW118
# 6788    800603       NaN
# 6789    80068b  IGO111
# 7061    800afb  JAI256
# 13346   800647       NaN
# 16080   8007f7  GOW321
# 19291   8005dd  IGO421
# 20816   800647  SEJ502
# ...        ...       ...
# 566801  800538  GOW115
# 566941  800624       NaN
# 566953  800624  IGO317
# 568720  80064c  IGO465
# 569443  800469       NaN
# 570789  8007c0  JAI466
# 572469  80047c       NaN
# 580971  8001d3  JAI450
# 583754  80067c       NaN
# 583926  80067c  JLL4056
# 585575  8004fd  AIC639
# 586734  8006e1       NaN
# 586754  8007dd       NaN
# 587067  8006e1  IGO407
# 587635  8001e6       NaN
# 587639  800031       NaN
# 587640  8005b8  SEJ282
# 587651  06a0aa       NaN
# 587667  80067c  JLL4165
# 587739  06a0aa  QTR938
# 587769  800031  AIC467
# 587786  8001e6  JLL4238
# 587901  80068a  IGO432
# 591818  800656  SEJ3304
# 591979  70c0a2  OMA253
# 592834  8007b7  LEP703
# 595703  8004fd  AIC265
# 596891  800589       NaN
# 597229  800589  AIC501
# 602644  800af6  SEJ215
#
# [282 rows x 2 columns]

# %%
type(data_hexcode_flight_noduplicates_NaN['hexcode'][0])
# Out:
# str

# %%
unique_hexcode[0]
# Out:
# '800b05'

# %%
len(unique_hexcode)
# Out:
# 130

# %%
len(data_hexcode_flight_noduplicates_NaN)
# Out:
# 282

# %%
data_hexcode_flight_noduplicates_NaN
# Out:
#        hexcode    flight
# 0       800b05       NaN
# 3       8006fc       NaN
# 19      8004fd       NaN
# 31      8004fb       NaN
# 47      8004b8       NaN
# 97      800b14       NaN
# 169     800549       NaN
# 350     800b05  BDA403
# 495     8004fd  AIC640
# 694     80015a       NaN
# 945     8004b8  SEJ442
# 2064    8001d9       NaN
# 3818    800549  GOW283
# 4289    8001d9  SEJ871
# 5477    800afb       NaN
# 5732    800af0       NaN
# 5824    8005dd       NaN
# 5920    800af0  IGO516
# 5989    4007f1       NaN
# 6559    80070f       NaN
# 6650    80047b       NaN
# 6690    8007f7       NaN
# 6761    4007f1  BAW118
# 6788    800603       NaN
# 6789    80068b  IGO111
# 7061    800afb  JAI256
# 13346   800647       NaN
# 16080   8007f7  GOW321
# 19291   8005dd  IGO421
# 20816   800647  SEJ502
# ...        ...       ...
# 566801  800538  GOW115
# 566941  800624       NaN
# 566953  800624  IGO317
# 568720  80064c  IGO465
# 569443  800469       NaN
# 570789  8007c0  JAI466
# 572469  80047c       NaN
# 580971  8001d3  JAI450
# 583754  80067c       NaN
# 583926  80067c  JLL4056
# 585575  8004fd  AIC639
# 586734  8006e1       NaN
# 586754  8007dd       NaN
# 587067  8006e1  IGO407
# 587635  8001e6       NaN
# 587639  800031       NaN
# 587640  8005b8  SEJ282
# 587651  06a0aa       NaN
# 587667  80067c  JLL4165
# 587739  06a0aa  QTR938
# 587769  800031  AIC467
# 587786  8001e6  JLL4238
# 587901  80068a  IGO432
# 591818  800656  SEJ3304
# 591979  70c0a2  OMA253
# 592834  8007b7  LEP703
# 595703  8004fd  AIC265
# 596891  800589       NaN
# 597229  800589  AIC501
# 602644  800af6  SEJ215
#
# [282 rows x 2 columns]

# %%
data_hexcode_flight_noduplicates_NaN = data_hexcode_flight_noduplicates_NaN.reset_index(drop=True)

# %%
data_hexcode_flight_noduplicates_NaN.flight = data_hexcode_flight_noduplicates_NaN.flight.str.strip() # remove unwanted blank spaces in string ex: 'ALK2671  ' to 'ALK2671''
data_hexcode_flight_noduplicates_NaN
# Out:
#     hexcode   flight
# 0    800b05      NaN
# 1    8006fc      NaN
# 2    8004fd      NaN
# 3    8004fb      NaN
# 4    8004b8      NaN
# 5    800b14      NaN
# 6    800549      NaN
# 7    800b05   BDA403
# 8    8004fd   AIC640
# 9    80015a      NaN
# 10   8004b8   SEJ442
# 11   8001d9      NaN
# 12   800549   GOW283
# 13   8001d9   SEJ871
# 14   800afb      NaN
# 15   800af0      NaN
# 16   8005dd      NaN
# 17   800af0   IGO516
# 18   4007f1      NaN
# 19   80070f      NaN
# 20   80047b      NaN
# 21   8007f7      NaN
# 22   4007f1   BAW118
# 23   800603      NaN
# 24   80068b   IGO111
# 25   800afb   JAI256
# 26   800647      NaN
# 27   8007f7   GOW321
# 28   8005dd   IGO421
# 29   800647   SEJ502
# ..      ...      ...
# 252  800538   GOW115
# 253  800624      NaN
# 254  800624   IGO317
# 255  80064c   IGO465
# 256  800469      NaN
# 257  8007c0   JAI466
# 258  80047c      NaN
# 259  8001d3   JAI450
# 260  80067c      NaN
# 261  80067c  JLL4056
# 262  8004fd   AIC639
# 263  8006e1      NaN
# 264  8007dd      NaN
# 265  8006e1   IGO407
# 266  8001e6      NaN
# 267  800031      NaN
# 268  8005b8   SEJ282
# 269  06a0aa      NaN
# 270  80067c  JLL4165
# 271  06a0aa   QTR938
# 272  800031   AIC467
# 273  8001e6  JLL4238
# 274  80068a   IGO432
# 275  800656  SEJ3304
# 276  70c0a2   OMA253
# 277  8007b7   LEP703
# 278  8004fd   AIC265
# 279  800589      NaN
# 280  800589   AIC501
# 281  800af6   SEJ215
#
# [282 rows x 2 columns]

# %%
hexcodevsflight = pd.DataFrame()
i = 0
for i in range(len(unique_hexcode)):
    
    vsflight = pd.Series()
    vsflight_withoutNaN = pd.Series() # a series to remove NaN in case of planes which have valid flight number.However, planes for which flight number was not decoded, NaN is retained 
    dictionary_flights = {}
    j=0
    
    for j in range(len(data_hexcode_flight_noduplicates_NaN)):
        if(unique_hexcode[i] == data_hexcode_flight_noduplicates_NaN['hexcode'][j]):
            vsflight = vsflight.append(pd.Series([data_hexcode_flight_noduplicates_NaN['flight'][j]]))
                     
    if(vsflight.size > 1):
        vsflight_withoutNaN = vsflight.dropna()
    else:
        vsflight_withoutNaN = vsflight
    
    vsflight_withoutNaN = vsflight_withoutNaN.tolist() # converting to list removes the unwanted index of 0 in every entry   
    dictionary_flights = {unique_hexcode[i] : vsflight_withoutNaN}        
    hexcodevsflight = hexcodevsflight.append([pd.Series([dictionary_flights])])

hexcodevsflight = hexcodevsflight.reset_index(drop=True)
hexcodevsflight.columns = ['planes']

print hexcodevsflight
#hexcodevsflight.to_csv('Planevsflight.csv')
# Out:
#                                                 planes
# 0                             {u'800b05': [u'BDA403']}
# 1                                   {u'8006fc': [nan]}
# 2       {u'8004fd': [u'AIC640', u'AIC639', u'AIC265']}
# 3                                   {u'8004fb': [nan]}
# 4                             {u'8004b8': [u'SEJ442']}
# 5                  {u'800b14': [u'IGO427', u'IGO428']}
# 6                             {u'800549': [u'GOW283']}
# 7                                   {u'80015a': [nan]}
# 8                             {u'8001d9': [u'SEJ871']}
# 9                  {u'800afb': [u'JAI256', u'JAI255']}
# 10                            {u'800af0': [u'IGO516']}
# 11                 {u'8005dd': [u'IGO421', u'IGO356']}
# 12                            {u'4007f1': [u'BAW118']}
# 13                            {u'80070f': [u'SEJ291']}
# 14                 {u'80047b': [u'AIC515', u'AIC517']}
# 15                 {u'8007f7': [u'GOW321', u'GOW116']}
# 16                            {u'800603': [u'IGO545']}
# 17                            {u'80068b': [u'IGO111']}
# 18                            {u'800647': [u'SEJ502']}
# 19   {u'8004cd': [u'JAI2735', u'JAI2400', u'JAI2755']}
# 20                            {u'800b1a': [u'JAI405']}
# 21                 {u'80052e': [u'AIC667', u'AIC668']}
# 22                 {u'8005b8': [u'SEJ281', u'SEJ282']}
# 23                                  {u'8006fe': [nan]}
# 24                            {u'800595': [u'IGO126']}
# 25                 {u'80053d': [u'AIC603', u'AIC604']}
# 26                            {u'8007f2': [u'JAI489']}
# 27                            {u'80003d': [u'AIC263']}
# 28                 {u'89609b': [u'UAE544', u'UAE545']}
# 29                 {u'800af9': [u'JAI411', u'JAI412']}
# ..                                                 ...
# 100                                 {u'8000c2': [nan]}
# 101                                 {u'8000c0': [nan]}
# 102                            {u'8004f8': [u'VTRVL']}
# 103                                 {u'80062b': [nan]}
# 104                           {u'800628': [u'IGO155']}
# 105                           {u'750204': [u'MAS174']}
# 106                                 {u'8004fa': [nan]}
# 107                                 {u'8007ef': [nan]}
# 108                           {u'06a052': [u'QTR845']}
# 109                           {u'8004bd': [u'AIC671']}
# 110                           {u'896310': [u'UAE433']}
# 111                           {u'80054d': [u'IGO238']}
# 112                           {u'80068c': [u'IGO461']}
# 113                           {u'8007f0': [u'SEJ451']}
# 114                           {u'89620d': [u'UAE409']}
# 115                           {u'896212': [u'UAE345']}
# 116                           {u'800538': [u'GOW115']}
# 117                           {u'80064c': [u'IGO465']}
# 118                          {u'30003a': [u'EXV9141']}
# 119                           {u'800624': [u'IGO317']}
# 120                                 {u'800469': [nan]}
# 121                                 {u'80047c': [nan]}
# 122              {u'80067c': [u'JLL4056', u'JLL4165']}
# 123                           {u'8006e1': [u'IGO407']}
# 124                                 {u'8007dd': [nan]}
# 125                          {u'8001e6': [u'JLL4238']}
# 126                           {u'800031': [u'AIC467']}
# 127                           {u'06a0aa': [u'QTR938']}
# 128                           {u'70c0a2': [u'OMA253']}
# 129                           {u'800589': [u'AIC501']}
#
# [130 rows x 1 columns]

# %%
hexcodevsflight.to_csv('planesvsflight.csv')
